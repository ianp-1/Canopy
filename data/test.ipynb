# %%
import pandas as pd
weekly = pd.read_csv("/data/PAd_2022_weekly_raw.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 weekly = pd.read_csv("/data/PAd_2022_weekly_raw.csv")
#
# NameError: name 'pd' is not defined
